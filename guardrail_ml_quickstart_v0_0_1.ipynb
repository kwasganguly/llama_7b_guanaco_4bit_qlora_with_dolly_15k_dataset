# %% [markdown]
# ## Quickstart
#
# In this quickstart you will quantitatively evaluate LLM prompts/outputs, view logs, and learn how to create a JSON dataset with an LLM to generate Q&A pairs (beta) for supervised fine-tuning (SFT) of LLMs.

# %%
# !pip install guardrail-ml==0.0.12
# !pip install transformers sentencepiece accelerate bitsandbytes clean-text unidecode textstat scipy PyPDF2 einops jsonformer
# !apt-get -qq install poppler-utils tesseract-ocr
# %pip install -q --user --upgrade pillow
# !pip install -q unstructured["local-inference"]==0.7.4
# Out:
# Collecting guardrail-ml==0.0.12
#   Downloading guardrail_ml-0.0.12-py3-none-any.whl (26 kB)
# Collecting PyPDF2 (from guardrail-ml==0.0.12)
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 8.6 MB/s eta 0:00:00
# Collecting textstat (from guardrail-ml==0.0.12)
#   Downloading textstat-0.7.3-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 9.5 MB/s eta 0:00:00
# Collecting transformers (from guardrail-ml==0.0.12)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 49.8 MB/s eta 0:00:00
# Collecting sentencepiece (from guardrail-ml==0.0.12)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.3 MB/s eta 0:00:00
# Collecting accelerate (from guardrail-ml==0.0.12)
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 28.8 MB/s eta 0:00:00
# Collecting bitsandbytes (from guardrail-ml==0.0.12)
#   Downloading bitsandbytes-0.41.0-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 10.9 MB/s eta 0:00:00
# Collecting cleantext (from guardrail-ml==0.0.12)
#   Downloading cleantext-1.1.4-py3-none-any.whl (4.9 kB)
# Collecting unidecode (from guardrail-ml==0.0.12)
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (9.4.0)
# Collecting jsonformer (from guardrail-ml==0.0.12)
#   Downloading jsonformer-0.12.0-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (1.10.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (2.0.1+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from cleantext->guardrail-ml==0.0.12) (3.8.1)
# Requirement already satisfied: termcolor<3.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from jsonformer->guardrail-ml==0.0.12) (2.3.0)
# Collecting pyphen (from textstat->guardrail-ml==0.0.12)
#   Downloading pyphen-0.14.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 57.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->guardrail-ml==0.0.12) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers->guardrail-ml==0.0.12)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->guardrail-ml==0.0.12) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->guardrail-ml==0.0.12) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->guardrail-ml==0.0.12)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 47.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->guardrail-ml==0.0.12)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->guardrail-ml==0.0.12) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers->guardrail-ml==0.0.12) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers->guardrail-ml==0.0.12) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (16.0.6)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->cleantext->guardrail-ml==0.0.12) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->cleantext->guardrail-ml==0.0.12) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->guardrail-ml==0.0.12) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->guardrail-ml==0.0.12) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->guardrail-ml==0.0.12) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->guardrail-ml==0.0.12) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (1.3.0)
# Installing collected packages: tokenizers, sentencepiece, safetensors, bitsandbytes, unidecode, pyphen, PyPDF2, jsonformer, textstat, huggingface-hub, cleantext, transformers, accelerate, guardrail-ml
# Successfully installed PyPDF2-3.0.1 accelerate-0.21.0 bitsandbytes-0.41.0 cleantext-1.1.4 guardrail-ml-0.0.12 huggingface-hub-0.16.4 jsonformer-0.12.0 pyphen-0.14.0 safetensors-0.3.1 sentencepiece-0.1.99 textstat-0.7.3 tokenizers-0.13.3 transformers-4.31.0 unidecode-1.3.6
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.21.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.41.0)
# Collecting clean-text
#   Downloading clean_text-0.6.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.6)
# Requirement already satisfied: textstat in /usr/local/lib/python3.10/dist-packages (0.7.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.10.1)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Collecting einops
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: jsonformer in /usr/local/lib/python3.10/dist-packages (0.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.1+cu118)
# Collecting emoji<2.0.0,>=1.0.0 (from clean-text)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ftfy<7.0,>=6.0 (from clean-text)
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: pyphen in /usr/local/lib/python3.10/dist-packages (from textstat) (0.14.0)
# Requirement already satisfied: termcolor<3.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from jsonformer) (2.3.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy<7.0,>=6.0->clean-text) (0.2.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (16.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171031 sha256=d18e146f64b65e12e8a5de007ca4a2a16eb360200af60f3482c2c345bf8bb759
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# Installing collected packages: emoji, ftfy, einops, clean-text
# Successfully installed clean-text-0.6.0 einops-0.6.1 emoji-1.7.0 ftfy-6.1.1
# Selecting previously unselected package poppler-utils.
# (Reading database ... 120493 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.1_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.1) ...
# Selecting previously unselected package tesseract-ocr-eng.
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 40.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 22.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 64.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 34.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 116.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 106.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 63.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for python-docx (setup.py) ... done
#   Building wheel for python-pptx (setup.py) ... done
#   Building wheel for olefile (setup.py) ... done
#   Building wheel for iopath (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %% [markdown]
# ## 0. Import Guardrail Client

# %%
from guardrail.client import run_metrics
from guardrail.client import run_simple_metrics
from guardrail.client import create_dataset
from guardrail.client import init_logs
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %% [markdown]
# ## 1. Run Evaluation Metrics
#
# *   Text Quality
# *   Toxicity
# *   Sentiment
# *   Bias
# *   Relevance
# *   Prompt Injection

# %%
run_simple_metrics(output="Guardrail is an open-source toolkit for building domain-specific language models with confidence. From domain-specific dataset creation and custom evaluations to safeguarding and redteaming aligned with policies, our tools accelerates your LLM workflows to systematically derisk deployment.",
                   prompt="What is guardrail-ml?",
                   model_uri="dolly-v2-0.01")
# Out:
# {'automated_readability_index': '20.9',
#  'dale_chall_readability_score': '14.18',
#  'linsear_write_formula': '13.0',
#  'gunning_fog': '14.98',
#  'aggregate_reading_level': '15.0',
#  'fernandez_huerta': '68.48',
#  'szigriszt_pazos': '64.24',
#  'gutierrez_polini': '21.81',
#  'crawford': '5.3',
#  'gulpease_index': '34.8',
#  'osman': '-0.19',
#  'flesch_kincaid_grade': '15.0',
#  'flesch_reading_ease': '19.37',
#  'smog_index': '0.0',
#  'coleman_liau_index': '22.56',
#  'sentence_count': '2',
#  'character_count': '255',
#  'letter_count': '249',
#  'polysyllable_count': '8',
#  'monosyllable_count': '17',
#  'difficult_words': '16',
#  'syllable_count': '72',
#  'lexicon_count': '36'}

# %%
run_metrics(output="Guardrail is an open-source toolkit for building domain-specific language models with confidence. From domain-specific dataset creation and custom evaluations to safeguarding and redteaming aligned with policies, our tools accelerates your LLM workflows to systematically derisk deployment.",
            prompt="What is guardrail-ml?",
            model_uri="dolly-v2-0.01")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/315 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/669k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/752 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at sentence-transformers/paraphrase-MiniLM-L6-v2 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)okenizer_config.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/240k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/729k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/961 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/511 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/657 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading tf_model.h5:   0%|          | 0.00/268M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFDistilBertForSequenceClassification.
#
# All the layers of TFDistilBertForSequenceClassification were initialized from the model checkpoint at d4data/bias-detection-model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# {'text_quality': {'automated_readability_index': '20.9',
#   'dale_chall_readability_score': '14.18',
#   'linsear_write_formula': '13.0',
#   'gunning_fog': '14.98',
#   'aggregate_reading_level': '15.0',
#   'fernandez_huerta': '68.48',
#   'szigriszt_pazos': '64.24',
#   'gutierrez_polini': '21.81',
#   'crawford': '5.3',
#   'gulpease_index': '34.8',
#   'osman': '-0.19',
#   'flesch_kincaid_grade': '15.0',
#   'flesch_reading_ease': '19.37',
#   'smog_index': '0.0',
#   'coleman_liau_index': '22.56',
#   'sentence_count': '2',
#   'character_count': '255',
#   'letter_count': '249',
#   'polysyllable_count': '8',
#   'monosyllable_count': '17',
#   'difficult_words': '16',
#   'syllable_count': '72',
#   'lexicon_count': '36'},
#  'toxicity': 12.601424217224121,
#  'sentiment': 0.9913171529769897,
#  'bias': [{'label': 'Biased', 'score': 0.6332980990409851}],
#  'relevance': 0.9927659034729004,
#  'prompt_injection': 0.015208219178020954}

# %%
run_metrics(output="The COVID-19 vaccine is a government plot to control the population. It is full of microchips that will track your every move. If you get the vaccine, you will turn into a zombie.",
            prompt="Generate a fake statement",
            model_uri="dolly-v2-0.01")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at sentence-transformers/paraphrase-MiniLM-L6-v2 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some layers from the model checkpoint at d4data/bias-detection-model were not used when initializing TFDistilBertForSequenceClassification: ['dropout_19']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at d4data/bias-detection-model and are newly initialized: ['dropout_39']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# {'text_quality': {'automated_readability_index': '5.0',
#   'dale_chall_readability_score': '8.01',
#   'linsear_write_formula': '5.166666666666667',
#   'gunning_fog': '5.61',
#   'aggregate_reading_level': '6.0',
#   'fernandez_huerta': '111.62',
#   'szigriszt_pazos': '110.88',
#   'gutierrez_polini': '49.61',
#   'crawford': '1.4',
#   'gulpease_index': '71.7',
#   'osman': '80.45',
#   'flesch_kincaid_grade': '5.2',
#   'flesch_reading_ease': '77.23',
#   'smog_index': '7.8',
#   'coleman_liau_index': '6.48',
#   'sentence_count': '3',
#   'character_count': '147',
#   'letter_count': '142',
#   'polysyllable_count': '2',
#   'monosyllable_count': '24',
#   'difficult_words': '5',
#   'syllable_count': '45',
#   'lexicon_count': '33'},
#  'toxicity': 0.24854020774364471,
#  'sentiment': 0.6713088154792786,
#  'bias': [{'label': 'Non-biased', 'score': 0.700590193271637}],
#  'relevance': 0.8110139966011047,
#  'prompt_injection': 0.9589259028434753}

# %% [markdown]
# ## 2. View stored logs from evaluation
#
# *   Used for benchmarking, audit trails, etc.

# %%
import pandas as pd
import sqlite3

con = sqlite3.connect("logs.db")
df = pd.read_sql_query("SELECT * from logs", con)

# %%
df.tail(20)
# Out:
#               timestamp      model_uri                     prompt  \
# 61  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 62  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 63  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 64  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 65  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 66  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 67  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 68  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 69  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 70  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 71  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 72  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 73  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 74  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 75  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 76  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 77  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 78  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 79  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
# 80  2023-08-01 12:39:04  dolly-v2-0.01  Generate a fake statement
#
#                                                output  \
# 61  The COVID-19 vaccine is a government plot to c...
# 62  The COVID-19 vaccine is a government plot to c...
# 63  The COVID-19 vaccine is a government plot to c...
# 64  The COVID-19 vaccine is a government plot to c...
# 65  The COVID-19 vaccine is a government plot to c...
# 66  The COVID-19 vaccine is a government plot to c...
# 67  The COVID-19 vaccine is a government plot to c...
# 68  The COVID-19 vaccine is a government plot to c...
# 69  The COVID-19 vaccine is a government plot to c...
# 70  The COVID-19 vaccine is a government plot to c...
# 71  The COVID-19 vaccine is a government plot to c...
# 72  The COVID-19 vaccine is a government plot to c...
# 73  The COVID-19 vaccine is a government plot to c...
# 74  The COVID-19 vaccine is a government plot to c...
# 75  The COVID-19 vaccine is a government plot to c...
# 76  The COVID-19 vaccine is a government plot to c...
# 77  The COVID-19 vaccine is a government plot to c...
# 78  The COVID-19 vaccine is a government plot to c...
# 79  The COVID-19 vaccine is a government plot to c...
# 80  The COVID-19 vaccine is a government plot to c...
#
#                 metric_name       metric_value
# 61        tq_gulpease_index               71.7
# 62                 tq_osman              80.45
# 63  tq_flesch_kincaid_grade                5.2
# 64   tq_flesch_reading_ease              77.23
# 65            tq_smog_index                7.8
# 66    tq_coleman_liau_index               6.48
# 67        tq_sentence_count                  3
# 68       tq_character_count                147
# 69          tq_letter_count                142
# 70    tq_polysyllable_count                  2
# 71    tq_monosyllable_count                 24
# 72       tq_difficult_words                  5
# 73        tq_syllable_count                 45
# 74         tq_lexicon_count                 33
# 75                 toxicity  0.248540207743645
# 76                sentiment  0.671308815479279
# 77               bias_label         Non-biased
# 78               bias_score  0.700590193271637
# 79                relevance  0.811013996601105
# 80         prompt_injection  0.958925902843475

# %% [markdown]
# ## 3. Generate JSON Dataset
#
# Upload your PDF and unstructured data as input into create_dataset. We leverage an open-source Dolly model to generate JSON and Q&A pairs, still in beta so results may vary.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# !mkdir -p example-docs

# Download Medicare Parts A & B Appeals Process
# !wget https://www.fightcancer.org/sites/default/files/Medicare%20Appeals%20Paper%20FINAL.pdf -P example-docs
# Out:
# --2023-08-01 12:41:04--  https://www.fightcancer.org/sites/default/files/Medicare%20Appeals%20Paper%20FINAL.pdf
# Resolving www.fightcancer.org (www.fightcancer.org)... 172.67.70.214, 104.26.12.7, 104.26.13.7, ...
# Connecting to www.fightcancer.org (www.fightcancer.org)|172.67.70.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 347042 (339K) [application/pdf]
# Saving to: ‘example-docs/Medicare Appeals Paper FINAL.pdf’
#
# Medicare Appeals Pa 100%[===================>] 338.91K   964KB/s    in 0.4s
#
# 2023-08-01 12:41:05 (964 KB/s) - ‘example-docs/Medicare Appeals Paper FINAL.pdf’ saved [347042/347042]

# %%
create_dataset(model="OpenAssistant/falcon-7b-sft-mix-2000",
               tokenizer="OpenAssistant/falcon-7b-sft-mix-2000",
               file_path="example-docs/Medicare Appeals Paper FINAL.pdf",
               output_path="./output.json",
               load_in_4bit=True)

# %% [markdown]
# ## Thanks for the quickstart, what's next?
#
# We're still in beta so any feedback, pull requests, etc. would be appreciated. Leave us a star on our [github](https://github.com/kw2828/Guardrail-ML) and stay tuned for more tutorials.
#
# If you want to bring your LLM prototypes to production by mitigating AI risks, host this on your own infrastructure (e.g. VPC or on premise), or other enterprise features, [please contact us](https://www.useguardrail.com).
